# %% [markdown]
# <a href="https://colab.research.google.com/github/CrzyHAX91/badspy.v3/blob/main/valid8proxy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/spyboy-productions/Valid8Proxy.git
# Out:
# Cloning into 'Valid8Proxy'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 123 (delta 56), reused 46 (delta 44), pack-reused 60 (from 1)
# Receiving objects: 100% (123/123), 1.05 MiB | 6.91 MiB/s, done.
# Resolving deltas: 100% (66/66), done.

# %%
cd Valid8Proxy
# Out:
# /content/Valid8Proxy

# %%
# !pip install -r requirements.txt

# %%
# !python Valid8Proxy.py
# Out:
#
#   ___ ___       __ __    __ _______ _______
#  |   Y   .---.-|  |__.--|  |   _   |   _   .----.-----.--.--.--.--.
#  |.  |   |  _  |  |  |  _  |.  |   |.  1   |   _|  _  |_   _|  |  |
#  |.  |   |___._|__|__|_____|.  _   |.  ____|__| |_____|__.__|___  |
#  |:  1   |                 |:  1   |:  |                    |_____|
#   \:.. ./                  |::.. . |::.|
#    `---'                   `-------`---'
#       fetching, validating, and storing working proxies.
#
#
#
# [+] Version      : 0.0.4
# [+] Created By   : Spyboy
#  ╰➤ Twitter      : https://spyboy.in/twitter
#  ╰➤ Discord      : https://spyboy.in/Discord
#  ╰➤ Website      : https://spyboy.in/
#  ╰➤ Blog         : https://spyboy.blog/
#  ╰➤ Github       : https://github.com/spyboy-productions/Valid8Proxy
#
# Let's find some validated proxies!
#
# Enter the number of proxies you want to print(ex: 5):5
#
# Choose the type of proxy:
# 1. HTTP
# 2. HTTPS
# 3. SOCKS4
# 4. SOCKS5
# 5. Mixed Proxies (recommended)
#
# ...
